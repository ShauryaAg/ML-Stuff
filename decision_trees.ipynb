# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
plt.rcParams['figure.figsize'] = 16, 9

print(plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names))
plt.show()
# Out:
# [Text(274.7076923076923, 454.2942857142857, 'petal length (cm) <= 2.45\ngini = 0.666\nsamples = 112\nvalue = [35, 39, 38]\nclass = versicolor'), Text(206.03076923076924, 384.40285714285716, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]\nclass = setosa'), Text(343.38461538461536, 384.40285714285716, 'petal length (cm) <= 4.75\ngini = 0.5\nsamples = 77\nvalue = [0, 39, 38]\nclass = versicolor'), Text(137.35384615384615, 314.51142857142855, 'petal width (cm) <= 1.65\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]\nclass = versicolor'), Text(68.67692307692307, 244.62, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]\nclass = versicolor'), Text(206.03076923076924, 244.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'), Text(549.4153846153846, 314.51142857142855, 'petal width (cm) <= 1.75\ngini = 0.21\nsamples = 42\nvalue = [0, 5, 37]\nclass = virginica'), Text(343.38461538461536, 244.62, 'petal length (cm) <= 4.95\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]\nclass = versicolor'), Text(274.7076923076923, 174.7285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'), Text(412.0615384615385, 174.7285714285714, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'), Text(343.38461538461536, 104.83714285714285, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'), Text(480.73846153846154, 104.83714285714285, 'petal length (cm) <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'), Text(412.0615384615385, 34.945714285714246, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'), Text(549.4153846153846, 34.945714285714246, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'), Text(755.4461538461538, 244.62, 'petal length (cm) <= 4.85\ngini = 0.057\nsamples = 34\nvalue = [0, 1, 33]\nclass = virginica'), Text(686.7692307692307, 174.7285714285714, 'sepal width (cm) <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'), Text(618.0923076923077, 104.83714285714285, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'), Text(755.4461538461538, 104.83714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'), Text(824.123076923077, 174.7285714285714, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]\nclass = virginica')]

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
confusion_matrix(y_train, y_train_pred)
# Out:
# array([[35,  0,  0],
#        [ 0, 39,  0],
#        [ 0,  0, 38]], dtype=int64)

# %%
confusion_matrix(y_test, y_test_pred)
# Out:
# array([[15,  0,  0],
#        [ 0, 11,  0],
#        [ 0,  0, 12]], dtype=int64)
